# %% [markdown]
# # 1.Explain the difference relative,Absoulute,and mixed cell referencing?
#
# Ans-
#
# # Relative Referance
#
# which changes automatically when the formula is copied to another cell.
#
# 1.Write Equal to SUM(B2:B4)
#
# 2.Will get sum of all the 3 vechicles as 53,550
#
# #Absolute Reference
#
# which does not changes when copied to another cell,it remains constant.
#
# 1.Write Equal to SUM(Dollar B2:Dollar B4)
#
# 2.Dollar is used in order to keep the values constant.
#
# 3.Will get sum as 53,550
#
#
# #Mixed referance
#
# changes either row or coloum,not both.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #2.Write aformula to calculate the total sales of car and bicycle only.
#
# Ans-
#
# 1.First write equal to SUM of B2 and B3 cell respective to car and bicyle price only.
#
# 2.i.e=SUM(B2:B3)
#
# 3.Will get answer as 510500.

# %% [markdown]
# #3.Using data below write formula to calculate the average sales of itemsprice above 100 but less than 300.
#
# Ans-
#
# 1. We need to equal to AVERAGE of price above 100 but less than 300 are Item B and Item C.
#
# 2.Formula =AVERAGE(C3:C4)
#
# 3.Will get AVERAGE as 1350
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Using the given dataset.
# #4. Count how many customers nsmes are recorded.
#
# Ans-
#
# 1.Write equal to COUNT and select all coustmers names coloum.
#
# 2.=COUNTA(A2:A5)
#
# 3.Will get answer as 50.

# %% [markdown]
# #5.Calculate the total sales of each row using Formula.
#
# Ans-
#
# 1.Make an another colomn of Total sales.
#
# 2.To calculate total sales=Quantity*Unit price.
#
# 3.=(E2 * F2),=(E3 * F3)etc.

# %% [markdown]
# #6. Calculate the total sales of Notebooks in the Northregion only.
#
# Ans-
#
# 1. we needs to insert an new column as sales in north region only.
#
# 2. Use equal to SUMIFS of total sales,products and region.
#
# 3. Formula =SUMIFS(I2:I5,D2:D51,"Notebook",C2:C51,"North").
#
# 4. Will get 2900 as result.

# %% [markdown]
# #7. Create a Column chart showing total sales by product.
#
# Ans-
#
# 1.Select the columns of total sales and product.
#
# 2.Insert and column chart containing the above.
#
# 3.X Axis - Products , Y Axis - Total sales.

# %% [markdown]
# #8.Insert an line chart showing daily sales trend.
#
# Ans -
#
# 1.Select the columns of Dates and Total sales.
#
# 2.Insert an line chart contating the above.
#
# 3.X Axis - Dates , Y Axis - Total Sales
